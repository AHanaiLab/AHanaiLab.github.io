# %% [markdown]
# # Pythonのfoliumで地図上にデータをマップする
# 参考にした記事:https://96lovefootball.hatenablog.com/entry/2019/03/17/210000?utm_source=feed

# %%
import folium

# %% [markdown]
# ### 国土交通省のホームページから、国土数値情報をダウンロード
# </br>https://nlftp.mlit.go.jp/ksj/gml/datalist/KsjTmplt-N03-v3_0.html#prefecture27

# %%
#対象とする県によって三つ変更するところがあります。あと、最後のコードを実行するには、（県のローマ字）_mapというフォルダを作る必要があります。
pref_name = "山梨"
pref_romaji = "yamanashi"
geojson = '/content/Data/N03-21_19_210101.geojson'

# %%
# 都道府県コード辞書
pref_code_dict = {
    '北海道': 1, '青森': 2, '岩手': 3, '宮城': 4, '秋田': 5,
    '山形': 6, '福島': 7, '茨城': 8, '栃木': 9, '群馬': 10,
    '埼玉': 11, '千葉': 12, '東京': 13, '神奈川': 14, '新潟': 15,
    '富山': 16, '石川': 17, '福井': 18, '山梨': 19, '長野': 20,
    '岐阜': 21, '静岡': 22, '愛知': 23, '三重': 24, '滋賀': 25,
    '京都': 26, '大阪': 27, '兵庫': 28, '奈良': 29, '和歌山': 30,
    '鳥取': 31, '島根': 32, '岡山': 33, '広島': 34, '山口': 35,
    '徳島': 36, '香川': 37, '愛媛': 38, '高知': 39, '福岡': 40,
    '佐賀': 41, '長崎': 42, '熊本': 43, '大分': 44, '宮崎': 45,
    '鹿児島': 46, '沖縄': 47
}

# 都道府県コードを文字列に
pref_code_str = str(pref_code_dict[pref_name]).zfill(2)




# 都道府県ごとの中心座標（例: 県庁所在地の緯度経度）
pref_location = {
    "北海道": [43.06417, 141.34694],  # 札幌市
    "青森": [40.82444, 140.74],     # 青森市
    "岩手": [39.70361, 141.1525],   # 盛岡市
    "宮城": [38.26889, 140.87194],  # 仙台市
    "秋田": [39.71861, 140.1025],
    "山形": [38.24056, 140.36333],
    "福島": [37.75, 140.46778],
    "茨城": [36.34139, 140.44667],
    "栃木": [36.56583, 139.88361],
    "群馬": [36.39111, 139.06083],
    "埼玉": [35.85694, 139.64889],
    "千葉": [35.60472, 140.12333],
    "東京都": [35.68944, 139.69167],
    "神奈川": [35.44778, 139.6425],
    "新潟": [37.90222, 139.02361],
    "富山": [36.69528, 137.21139],
    "石川": [36.59444, 136.62556],
    "福井": [36.06528, 136.22194],
    "山梨": [35.66389, 138.56833],  # 甲府市
    "長野": [36.65139, 138.18111],
    "岐阜": [35.39111, 136.72222],
    "静岡": [34.97694, 138.38306],
    "愛知": [35.18028, 136.90667],
    "三重": [34.73028, 136.50861],
    "滋賀": [35.00444, 135.86833],
    "京都": [35.02139, 135.75556],
    "大阪": [34.68639, 135.52],
    "兵庫": [34.69139, 135.18306],
    "奈良": [34.68528, 135.83278],
    "和歌山": [34.22611, 135.1675],
    "鳥取": [35.50361, 134.23833],
    "島根": [35.47222, 133.05056],
    "岡山": [34.66167, 133.935],
    "広島": [34.39639, 132.45944],
    "山口": [34.18583, 131.47139],
    "徳島": [34.06583, 134.55944],
    "香川": [34.34028, 134.04333],
    "愛媛": [33.84167, 132.76611],
    "高知": [33.55972, 133.53111],
    "福岡": [33.60639, 130.41806],
    "佐賀": [33.24944, 130.29889],
    "長崎": [32.74472, 129.87361],
    "熊本": [32.78972, 130.74167],
    "大分": [33.23806, 131.6125],
    "宮崎": [31.91111, 131.42389],
    "鹿児島": [31.56028, 130.55806],
    "沖縄": [26.2125, 127.68111]
}

# %%
location = pref_location[pref_name]

# %%
import pandas as pd

# %%
#地図上にマップするデータをcsvから読み込む
data = pd.read_csv('/content/Data/Social_life_statistics_index.csv')

# %%
#データの確認
data.head()
# Out:
#    @area  可住地面積１k�F当たり人口密度  昼夜間人口比率  外国人人口（人口１０万人当たり）  １５歳未満人口割合  １５〜６４歳人口割合  \
# 0   1100            4433.5    100.4             451.8     11.320      63.283
# 1   1101            8856.8    162.7             795.8     10.099      67.475
# 2   1102            4515.3     95.9             709.0     11.536      62.719
# 3   1103            4598.2     94.6             428.0     11.728      64.259
# 4   1104            6090.8     98.6             283.9     11.256      65.310
#
#    ６５歳以上人口割合  未婚者割合（15歳以上人口）  人口増減率  転入超過率  ...  １住宅当たりの延べ面積  \
# 0     24.767        29.83508   2.03   0.42  ...        80.30
# 1     21.267        36.29654   7.92   1.39  ...        66.96
# 2     24.169        30.80597   2.35   0.46  ...        82.41
# 3     23.461        30.39551   2.36   0.57  ...        77.22
# 4     22.845        31.27262   2.61   0.21  ...        70.69
#
#    小売店数（事業所・企業統計調査結果）（人口千人当たり）  飲食店数（事業所・企業統計調査結果）（人口千人当たり）  \
# 0                        5.815                         4.51
# 1                       13.670                        17.74
# 2                        4.925                         3.31
# 3                        5.130                         2.31
# 4                        5.095                         2.80
#
#    大型小売店数（事業所・企業統計調査結果）（人口10万人当たり）  百貨店数（事業所・企業統計調査結果）（人口10万人当たり）  \
# 0                           18.745                           1.59
# 1                           31.145                           3.79
# 2                           16.995                           0.70
# 3                           19.090                           1.72
# 4                           13.595                           0.48
#
#    一般病院数（人口10万人当たり）  一般診療所数（人口10万人当たり）  一般病院数（可住地面積100k�F当たり）  \
# 0               9.2               67.5                  40.54
# 1              13.9              143.9                 127.42
# 2               6.7               61.3                  30.10
# 3               8.8               52.7                  38.62
# 4               8.6               50.1                  52.30
#
#    一般診療所数（可住地面積100k�F当たり）  介護老人福祉施設（65歳以上人口10万人当たり）
# 0                  303.18                      12.2
# 1                 1314.34                       7.9
# 2                  278.52                      11.6
# 3                  241.60                      11.4
# 4                  320.24                      10.4
#
# [5 rows x 47 columns]

# %%
m = folium.Map(location=location,tiles='cartodbpositron',zoom_start=10)

folium.Choropleth(
    geo_data=geojson,
    name='choropleth',
    data=data,
    columns=['@area', '昼夜間人口比率'],
    key_on='feature.properties.N03_007',
    fill_color='YlGnBu'
).add_to(m)

folium.LayerControl().add_to(m)

m.save(f'./{pref_romaji}_location.html')

# %% [markdown]
# #### 色が変わらない、、、、？？？ </br>
# 以前の色付けしたデータと見比べてみたところ、どうやら@areaコードの先頭0がないことが原因ぽい

'04606', '05201', '05202', '05203', '05204', '05206', '05207', '05209', '05210', '05211', '05212', '05213', '05214', '05215', '05303', '05327', '05346', '05348', '05349', '05361', '05363', '05366', '05368', '05434', '05463', '05464', '06201', '06202', '06203', '06204', '06205', '06206', '06207', '06208', '06209', '06210', '06211', '06212', '06213', '06301', '06302', '06321', '06322', '06323', '06324', '06341', '06361', '06362', '06363', '06364', '06365', '06366', '06367', '06381', '06382', '06401', '06402', '06403', '06426', '06428', '06461', '07201', '07202', '07203', '07204', '07205', '07207', '07208', '07209', '07210', '07211', '07212', '07213', '07214', '07301', '07303', '07308', '07322', '07342', '07344', '07362', '07364', '07367', '07368', '07402', '07405', '07407', '07408', '07421', '07422', '07423', '07444', '07445', '07446', '07447', '07461', '07464', '07465', '07466', '07481', '07482', '07483', '07484', '07501', '07502', '07503', '07504', '07505', '07521', '07522', '07541', '07542', '07543', '07544', '07545', '07546', '07547', '07548', '07561', '07564', '08201', '08202', '08203', '08204', '08205', '08207', '08208', '08210', '08211', '08212', '08214', '08215', '08216', '08217', '08219', '08220', '08221', '08222', '08223', '08224', '08225', '08226', '08227', '08 ...

# %%
#元のデータフレームと長さが一致しているか確認
len(area)
# Out:
# 1917

# %%
#データフレームにareaと言う列を足し、そこに上記の０補完したデータを入れる
data['area'] = area

# %%
#area列が入り、0補完されている事を確認
data.head()
# Out:
#    @area  可住地面積１k�F当たり人口密度  昼夜間人口比率  外国人人口（人口１０万人当たり）  １５歳未満人口割合  １５〜６４歳人口割合  \
# 0   1100            4433.5    100.4             451.8     11.320      63.283
# 1   1101            8856.8    162.7             795.8     10.099      67.475
# 2   1102            4515.3     95.9             709.0     11.536      62.719
# 3   1103            4598.2     94.6             428.0     11.728      64.259
# 4   1104            6090.8     98.6             283.9     11.256      65.310
#
#    ６５歳以上人口割合  未婚者割合（15歳以上人口）  人口増減率  転入超過率  ...  小売店数（事業所・企業統計調査結果）（人口千人当たり）  \
# 0     24.767        29.83508   2.03   0.42  ...                        5.815
# 1     21.267        36.29654   7.92   1.39  ...                       13.670
# 2     24.169        30.80597   2.35   0.46  ...                        4.925
# 3     23.461        30.39551   2.36   0.57  ...                        5.130
# 4     22.845        31.27262   2.61   0.21  ...                        5.095
#
#    飲食店数（事業所・企業統計調査結果）（人口千人当たり）  大型小売店数（事業所・企業統計調査結果）（人口10万人当たり）  \
# 0                         4.51                           18.745
# 1                        17.74                           31.145
# 2                         3.31                           16.995
# 3                         2.31                           19.090
# 4                         2.80                           13.595
#
#    百貨店数（事業所・企業統計調査結果）（人口10万人当たり）  一般病院数（人口10万人当たり）  一般診療所数（人口10万人当たり）  \
# 0                           1.59               9.2               67.5
# 1                           3.79              13.9              143.9
# 2                           0.70               6.7               61.3
# 3                           1.72               8.8               52.7
# 4                           0.48               8.6               50.1
#
#    一般病院数（可住地面積100k�F当たり）  一般診療所数（可住地面積100k�F当たり）  介護老人福祉施設（65歳以上人口10万人当たり）  \
# 0                  40.54                  303.18                      12.2
# 1                 127.42                 1314.34                       7.9
# 2                  30.10                  278.52                      11.6
# 3                  38.62                  241.60                      11.4
# 4                  52.30                  320.24                      10.4
#
#     area
# 0  01100
# 1  01101
# 2  01102
# 3  01103
# 4  01104
#
# [5 rows x 48 columns]

# %%
#列名確認
data.columns
# Out:
# Index(['@area', '可住地面積１k�F当たり人口密度', '昼夜間人口比率', '外国人人口（人口１０万人当たり）', '１５歳未満人口割合',
#        '１５〜６４歳人口割合', '６５歳以上人口割合', '未婚者割合（15歳以上人口）', '人口増減率', '転入超過率', '転入率',
#        '転出率', '核家族世帯割合', '高齢夫婦のみの世帯の割合', '高齢単身世帯の割合', '総面積（都道府県面積に占める割合）',
#        '可住地面積割合', '商業年間商品販売額［卸売業＋小売業］（従業者１人当たり）', '商業年間商品販売額［卸売業＋小売業］（事業所当たり）',
#        '課税対象所得（納税義務者１人当たり）', '標準財政規模（市町村財政）', '小学校数（可住地面積100k�F当たり）',
#        '中学校数（可住地面積100k�F当たり）', '高等学校数（可住地面積100k�F当たり）', '就業者比率',
#        '第１次産業就業者比率（対就業者）', '第２次産業就業者比率（対就業者）', '第３次産業就業者比率（対就業者）',
#        '第２次産業及び第３次産業就業者比率（対就業者）', '完全失業率', '他市区町村への通勤者比率', '他市区町村からの通勤者比率',
#        '高齢就業者割合［６５歳以上］', '公民館数（人口100万人当たり）', '図書館数（人口100万人当たり）', '持ち家比率',
#        '空き家比率（対総住宅数）', '１住宅当たりの延べ面積', '小売店数（事業所・企業統計調査結果）（人口千人当たり）',
#        '飲食店数（事業所・企業統計調査結果）（人口千人当たり）', '大型小売店数（事業所・企業統計調査結果）（人口10万人当たり）',
#        '百貨店数（事業所・企業統計調査結果）（人口10万人当たり）', '一般病院数（人口10万人当たり）',
#        '一般診療所数（人口10万人当たり）', '一般病院数（可住地面積100k�F当たり）', '一般診療所数（可住地面積100k�F当たり）',
#        '介護老人福祉施設（65歳以上人口10万人当たり）', 'area'],
#       dtype='object')

# %%
# data からその都道府県の自治体だけ抽出
data_prefecture = data[data["area"].astype(str).str.startswith(pref_code_str)]

# %%
data_prefecture.columns
# Out:
# Index(['@area', '可住地面積１k�F当たり人口密度', '昼夜間人口比率', '外国人人口（人口１０万人当たり）', '１５歳未満人口割合',
#        '１５〜６４歳人口割合', '６５歳以上人口割合', '未婚者割合（15歳以上人口）', '人口増減率', '転入超過率', '転入率',
#        '転出率', '核家族世帯割合', '高齢夫婦のみの世帯の割合', '高齢単身世帯の割合', '総面積（都道府県面積に占める割合）',
#        '可住地面積割合', '商業年間商品販売額［卸売業＋小売業］（従業者１人当たり）', '商業年間商品販売額［卸売業＋小売業］（事業所当たり）',
#        '課税対象所得（納税義務者１人当たり）', '標準財政規模（市町村財政）', '小学校数（可住地面積100k�F当たり）',
#        '中学校数（可住地面積100k�F当たり）', '高等学校数（可住地面積100k�F当たり）', '就業者比率',
#        '第１次産業就業者比率（対就業者）', '第２次産業就業者比率（対就業者）', '第３次産業就業者比率（対就業者）',
#        '第２次産業及び第３次産業就業者比率（対就業者）', '完全失業率', '他市区町村への通勤者比率', '他市区町村からの通勤者比率',
#        '高齢就業者割合［６５歳以上］', '公民館数（人口100万人当たり）', '図書館数（人口100万人当たり）', '持ち家比率',
#        '空き家比率（対総住宅数）', '１住宅当たりの延べ面積', '小売店数（事業所・企業統計調査結果）（人口千人当たり）',
#        '飲食店数（事業所・企業統計調査結果）（人口千人当たり）', '大型小売店数（事業所・企業統計調査結果）（人口10万人当たり）',
#        '百貨店数（事業所・企業統計調査結果）（人口10万人当たり）', '一般病院数（人口10万人当たり）',
#        '一般診療所数（人口10万人当たり）', '一般病院数（可住地面積100k�F当たり）', '一般診療所数（可住地面積100k�F当たり）',
#        '介護老人福祉施設（65歳以上人口10万人当たり）', 'area'],
#       dtype='object')

# %%
#列名をcol_nameに格納
col_name = data_prefecture.columns

# %%
#listの長さを確認
len(col_name)
# Out:
# 48

# %%
#最初と最後の列名が入っていることを確認
print(col_name[0])
print(col_name[47])
# Out:
# @area
# area

# %%
#適当な列番号（22)でマップしてみる
#columnsの引数には、新しく追加した列（col_name[47]を指定する！
# コピーして操作
df_tmp = data_prefecture.copy()


# 列番号22のデータを10分位化
df_tmp["区分"] = pd.qcut(
    df_tmp[col_name[22]],
    q=10,
    labels=False,  # 0〜9
    duplicates="drop"  # 値が少なくて重複する場合は自動調整
)


# Foliumマップ作成
m = folium.Map(location=location, tiles='cartodbpositron', zoom_start=10)
folium.Choropleth(
    geo_data=geojson,  # 対象県のGeoJSON
    name='choropleth',
    data=df_tmp,
    columns=[col_name[47], "区分"],  # col_name[47]は地域コード列
    key_on='feature.properties.N03_007',  # GeoJSONの自治体コードキー
    fill_color='YlGnBu'
).add_to(m)
folium.LayerControl().add_to(m)

m.save(f'./{pref_romaji}_'+col_name[22]+'.html')

# %%
for i in range(1, len(col_name)-1):
    # データコピー
    df_tmp = data_prefecture.copy()

    # 10分位化
    df_tmp["区分"] = pd.qcut(
        df_tmp[col_name[i]],
        q=10,
        labels=False,  # 0〜9
        duplicates="drop"  # 値が少なくて重複する場合は自動調整
    )

    # Foliumマップ作成
    m = folium.Map(location=location, tiles='cartodbpositron', zoom_start=10)
    folium.Choropleth(
        geo_data=geojson,  # 対象県のGeoJSON
        name='choropleth',
        data=df_tmp,
        columns=[col_name[47], "区分"],  # col_name[47]は地域コード列
        key_on='feature.properties.N03_007',  # GeoJSONの自治体コードキー
        fill_color='YlGnBu'
    ).add_to(m)
    folium.LayerControl().add_to(m)

    # 保存
    output_path = f'{pref_romaji}_map/{pref_romaji}_{col_name[i]}_qcut.html'
    print(output_path)
    m.save(output_path)
# Out:
# yamanashi_map/yamanashi_可住地面積１k�F当たり人口密度_qcut.html
# yamanashi_map/yamanashi_昼夜間人口比率_qcut.html
# yamanashi_map/yamanashi_外国人人口（人口１０万人当たり）_qcut.html
# yamanashi_map/yamanashi_１５歳未満人口割合_qcut.html
# yamanashi_map/yamanashi_１５〜６４歳人口割合_qcut.html
